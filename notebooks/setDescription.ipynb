# %% [markdown]
# # This notebook contains code examples for maintaining, extending and updating the Wikipathways bot

# %% [markdown]
# ## load the libraries

# %%
from wikidataintegrator import wdi_core, wdi_login
import os
import pandas as pd
import pprint

# %% [markdown]
# ## Define the functions

# %%
def sparql(query, endpoint):
    query=query
    return wdi_core.WDItemEngine.execute_sparql_query(query, endpoint=endpoint)

def sparqlpandas(query, endpoint):
    return wdi_core.WDItemEngine.execute_sparql_query(query, endpoint=endpoint, as_dataframe=True)

# %% [markdown]
# ## Login to the bot
# The code snippet below is to login in to Wikidata. First it checks if a local variable containing the wikidata user/bot account and password has been set. In this code example in the jupyter Notebook is use the [%env magic](https://stackoverflow.com/a/44251637/155046). In jenkins the variables are set when configuring the jenkins recipe.
#
# Running a script like this on Wikidata requires a [bot account](https://www.wikidata.org/wiki/Wikidata:Bots).

# %%
print("Logging in...")
if "WDUSER" in os.environ and "WDPASS" in os.environ:
    WDUSER = os.environ['WDUSER']
    WDPASS = os.environ['WDPASS']
else:
    raise ValueError("WDUSER and WDPASS must be specified in local.py or as environment variables")
login = wdi_login.WDLogin(WDUSER, WDPASS)
# Out:
# Logging in...
# https://www.wikidata.org/w/api.php
# Successfully logged in as Andrawaag

# %% [markdown]
# ## Update the description for Pathway http://identifiers.org/wikipathways/WP716

# %%
## Find the Wikidata identifier for WP716
query = """
   SELECT * WHERE {?pathway wdt:P2888 <http://identifiers.org/wikipathways/WP716>}
"""
sparqlpandas(query, endpoint="https://query.wikidata.org/sparql")
# Out:
#                                     pathway
# 0  http://www.wikidata.org/entity/Q27436284

# %%
wdwpid = sparql(query, endpoint="https://query.wikidata.org/sparql")["results"]["bindings"][0]["pathway"]["value"]
print(wdwpid)
# Out:
# http://www.wikidata.org/entity/Q27436284

# %%
wdPage = wdi_core.WDItemEngine(wd_item_id=wdwpid.replace("http://www.wikidata.org/entity/", ""))
pprint.pprint(wdPage.get_wd_json_representation())
# Out:
# {'aliases': {},
#  'claims': {'P1343': [{'id': 'Q27436284$45ca74de-4520-77f2-a64b-1ae8ce6cf171',
#                        'mainsnak': {'datatype': 'wikibase-item',
#                                     'datavalue': {'type': 'wikibase-entityid',
#                                                   'value': {'entity-type': 'item',
#                                                             'id': 'Q27436295',
#                                                             'numeric-id': 27436295}},
#                                     'property': 'P1343',
#                                     'snaktype': 'value'},
#                        'qualifiers': {},
#                        'qualifiers-order': [],
#                        'rank': 'normal',
#                        'references': [{'hash': '0e5141c6b678a71885036c39189e6e58c2a524ee',
#                                        'snaks': {'P248': [{'datatype': 'wikibase-item',
#                                                            'datavalue': {'type': 'wikibase-entityid',
#                                                                          'value': {'entity-type': 'item',
#                                                                                    'id': 'Q7999828',
#                                                                                    'numeric-id': 7999828}},
#                                                            'property': 'P248',
#                                                            'snaktype': 'value'}],
#                                                  'P813': [{'datatype': 'time',
#                                                            'datavalue': {'type': 'time',
#                                                                          'value': {'after': 0,
#                                                                                    'before': 0,
#                                                                                    'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                    'precision': 11,
#                                                                                    'time': '+2016-10-18T00:00:00Z',
#                                                                                    'timezone': 0}},
#                                                            'property': 'P813',
#                                                            'snaktype': 'value'}],
#                                                  'P854': [{'datatype': 'url',
#                                                            'datavalue': {'type': 'string',
#                                                                          'value': 'http://www.wikipathways.org/index.php/Pathway:WP716'},
#                                                            'property': 'P854',
#                                                            'snaktype': 'value'}]},
#                                        'snaks-order': ['P248',
#                                                        'P813',
#                                                        'P854']}],
#                        'type': 'statement'}],
#             'P1476': [{'id': 'Q27436284$034E5CF8-3EAA-4901-9EEB-E3091A09EB9C',
#                        'mainsnak': {'datatype': 'monolingualtext',
#                                     'datavalue': {'type': 'monolingualtext',
#                                                   'value': {'language': 'en',
#                                                             'text': 'Vitamin A '
#                                                                     'and '
#                                                                     'Carotenoid '
#                                                                     'Metabolism'}},
#                                     'property': 'P1476',
#                                     'snaktype': 'value'},
#                        'qualifiers': {},
#                        'qualifiers-order': [],
#                        'rank': 'normal',
#                        'references': [{'hash': 'e962d25052597ff81181c05c277866d8e0870606',
#                                        'snaks': {'P2410': [{'datatype': 'string',
#                                                             'datavalue': {'type': 'string',
#                                                                           'value': 'WP716'},
#                                                             'property': 'P2410',
#                                                             'snaktype': 'value'}],
#                                                  'P248': [{'datatype': 'wikibase-item',
#                                                            'datavalue': {'type': 'wikibase-entityid',
#                                                                          'value': {'entity-type': 'item',
#                                                                                    'id': 'Q7999828',
#                                                                                    'numeric-id': 7999828}},
#                                                            'property': 'P248',
#                                                            'snaktype': 'value'}],
#                                                  'P813': [{'datatype': 'time',
#                                                            'datavalue': {'type': 'time',
#                                                                          'value': {'after': 0,
#                                                                                    'before': 0,
#                                                                                    'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                    'precision': 11,
#                                                                                    'time': '+2019-09-04T00:00:00Z',
#                                                                                    'timezone': 0}},
#                                                            'property': 'P813',
#                                                            'snaktype': 'value'}]},
#                                        'snaks-order': ['P248',
#                                                        'P813',
#                                                        'P2410']}],
#                        'type': 'statement'}],
#             'P2410': [{'id': 'Q27436284$0bb98478-4265-cd8c-abfb-c5acfbab8106',
#                        'mainsnak': {'datatype': 'string',
#                                     'datavalue': {'type': 'string',
#                                                   'value': 'WP716'},
#                                     'property': 'P2410',
#                                     'snaktype': 'value'},
#                        'qualifiers': {},
#                        'qualifiers-order': [],
#                        'rank': 'normal',
#                        'references': [{'hash': 'e962d25052597ff81181c05c277866d8e0870606',
#                                        'snaks': {'P2410': [{'datatype': 'string',
#                                                             'datavalue': {'type': 'string',
#                                                                           'value': 'WP716'},
#                                                             'property': 'P2410',
#                                                             'snaktype': 'value'}],
#                                                  'P248': [{'datatype': 'wikibase-item',
#                                                            'datavalue': {'type': 'wikibase-entityid',
#                                                                          'value': {'entity-type': 'item',
#                                                                                    'id': 'Q7999828',
#                                                                                    'numeric-id': 7999828}},
#                                                            'property': 'P248',
#                                                            'snaktype': 'value'}],
#                                                  'P813': [{'datatype': 'time',
#                                                            'datavalue': {'type': 'time',
#                                                                          'value': {'after': 0,
#                                                                                    'before': 0,
#                                                                                    'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                    'precision': 11,
#                                                                                    'time': '+2019-09-04T00:00:00Z',
#                                                                                    'timezone': 0}},
#                                                            'property': 'P813',
#                                                            'snaktype': 'value'}]},
#                                        'snaks-order': ['P248',
#                                                        'P813',
#                                                        'P2410']}],
#                        'type': 'statement'}],
#             'P2860': [{'id': 'Q27436284$b222ad36-41e1-a719-3c44-494eeda8991c',
#                        'mainsnak': {'datatype': 'wikibase-item',
#                                     'datavalue': {'type': 'wikibase-entityid',
#                                                   'value': {'entity-type': 'item',
#                                                             'id': 'Q27436295',
#                                                             'numeric-id': 27436295}},
#                                     'property': 'P2860',
#                                     'snaktype': 'value'},
#                        'qualifiers': {},
#                        'qualifiers-order': [],
#                        'rank': 'normal',
#                        'references': [{'hash': 'e962d25052597ff81181c05c277866d8e0870606',
#                                        'snaks': {'P2410': [{'datatype': 'string',
#                                                             'datavalue': {'type': 'string',
#                                                                           'value': 'WP716'},
#                                                             'property': 'P2410',
#                                                             'snaktype': 'value'}],
#                                                  'P248': [{'datatype': 'wikibase-item',
#                                                            'datavalue': {'type': 'wikibase-entityid',
#                                                                          'value': {'entity-type': 'item',
#                                                                                    'id': 'Q7999828',
#                                                                                    'numeric-id': 7999828}},
#                                                            'property': 'P248',
#                                                            'snaktype': 'value'}],
#                                                  'P813': [{'datatype': 'time',
#                                                            'datavalue': {'type': 'time',
#                                                                          'value': {'after': 0,
#                                                                                    'before': 0,
#                                                                                    'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                    'precision': 11,
#                                                                                    'time': '+2019-09-04T00:00:00Z',
#                                                                                    'timezone': 0}},
#                                                            'property': 'P813',
#                                                            'snaktype': 'value'}]},
#                                        'snaks-order': ['P248',
#                                                        'P813',
#                                                        'P2410']}],
#                        'type': 'statement'},
#                       {'id': 'Q27436284$cce6dad5-4fe3-ac49-b112-286b5f2d5899',
#                        'mainsnak': {'datatype': 'wikibase-item',
#                                     'datavalue': {'type': 'wikibase-entityid',
#                                                   'value': {'entity-type': 'item',
#                                                             'id': 'Q27436301',
#                                                             'numeric-id': 27436301}},
#                                     'property': 'P2860',
#                                     'snaktype': 'value'},
#                        'qualifiers': {},
#                        'qualifiers-order': [],
#                        'rank': 'normal',
#                        'references': [{'hash': 'e962d25052597ff81181c05c277866d8e0870606',
#                                        'snaks': {'P2410': [{'datatype': 'string',
#                                                             'datavalue': {'type': 'string',
#                                                                           'value': 'WP716'},
#                                                             'property': 'P2410',
#                                                             'snaktype': 'value'}],
#                                                  'P248': [{'datatype': 'wikibase-item',
#                                                            'datavalue': {'type': 'wikibase-entityid',
#                                                                          'value': {'entity-type': 'item',
#                                                                                    'id': 'Q7999828',
#                                                                                    'numeric-id': 7999828}},
#                                                            'property': 'P248',
#                                                            'snaktype': 'value'}],
#                                                  'P813': [{'datatype': 'time',
#                                                            'datavalue': {'type': 'time',
#                                                                          'value': {'after': 0,
#                                                                                    'before': 0,
#                                                                                    'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                    'precision': 11,
#                                                                                    'time': '+2019-09-04T00:00:00Z',
#                                                                                    'timezone': 0}},
#                                                            'property': 'P813',
#                                                            'snaktype': 'value'}]},
#                                        'snaks-order': ['P248',
#                                                        'P813',
#                                                        'P2410']}],
#                        'type': 'statement'},
#                       {'id': 'Q27436284$F41D9F61-4148-48F1-B527-8C9DFBB7E6EF',
#                        'mainsnak': {'datatype': 'wikibase-item',
#                                     'datavalue': {'type': 'wikibase-entityid',
#                                                   'value': {'entity-type': 'item',
#                                                             'id': 'Q28609429',
#                                                             'numeric-id': 28609429}},
#                                     'property': 'P2860',
#                                     'snaktype': 'value'},
#                        'qualifiers': {},
#                        'qualifiers-order': [],
#                        'rank': 'normal',
#                        'references': [{'hash': 'e962d25052597ff81181c05c277866d8e0870606',
#                                        'snaks': {'P2410': [{'datatype': 'string',
#                                                             'datavalue': {'type': 'string',
#                                                                           'value': 'WP716'},
#                                                             'property': 'P2410',
#                                                             'snaktype': 'value'}],
#                                                  'P248': [{'datatype': 'wikibase-item',
#                                                            'datavalue': {'type': 'wikibase-entityid',
#                                                                          'value': {'entity-type': 'item',
#                                                                                    'id': 'Q7999828',
#                                                                                    'numeric-id': 7999828}},
#                                                            'property': 'P248',
#                                                            'snaktype': 'value'}],
#                                                  'P813': [{'datatype': 'time',
#                                                            'datavalue': {'type': 'time',
#                                                                          'value': {'after': 0,
#                                                                                    'before': 0,
#                                                                                    'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                    'precision': 11,
#                                                                                    'time': '+2019-09-04T00:00:00Z',
#                                                                                    'timezone': 0}},
#                                                            'property': 'P813',
#                                                            'snaktype': 'value'}]},
#                                        'snaks-order': ['P248',
#                                                        'P813',
#                                                        'P2410']}],
#                        'type': 'statement'},
#                       {'id': 'Q27436284$7ECAC01E-5016-4DD4-906D-66AA3C8E7425',
#                        'mainsnak': {'datatype': 'wikibase-item',
#                                     'datavalue': {'type': 'wikibase-entityid',
#                                                   'value': {'entity-type': 'item',
#                                                             'id': 'Q28609504',
#                                                             'numeric-id': 28609504}},
#                                     'property': 'P2860',
#                                     'snaktype': 'value'},
#                        'qualifiers': {},
#                        'qualifiers-order': [],
#                        'rank': 'normal',
#                        'references': [{'hash': 'e962d25052597ff81181c05c277866d8e0870606',
#                                        'snaks': {'P2410': [{'datatype': 'string',
#                                                             'datavalue': {'type': 'string',
#                                                                           'value': 'WP716'},
#                                                             'property': 'P2410',
#                                                             'snaktype': 'value'}],
#                                                  'P248': [{'datatype': 'wikibase-item',
#                                                            'datavalue': {'type': 'wikibase-entityid',
#                                                                          'value': {'entity-type': 'item',
#                                                                                    'id': 'Q7999828',
#                                                                                    'numeric-id': 7999828}},
#                                                            'property': 'P248',
#                                                            'snaktype': 'value'}],
#                                                  'P813': [{'datatype': 'time',
#                                                            'datavalue': {'type': 'time',
#                                                                          'value': {'after': 0,
#                                                                                    'before': 0,
#                                                                                    'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                    'precision': 11,
#                                                                                    'time': '+2019-09-04T00:00:00Z',
#                                                                                    'timezone': 0}},
#                                                            'property': 'P813',
#                                                            'snaktype': 'value'}]},
#                                        'snaks-order': ['P248',
#                                                        'P813',
#                                                        'P2410']}],
#                        'type': 'statement'},
#                       {'id': 'Q27436284$38625612-AC80-4C18-BC62-13EC8CB83F3C',
#                        'mainsnak': {'datatype': 'wikibase-item',
#                                     'datavalue': {'type': 'wikibase-entityid',
#                                                   'value': {'entity-type': 'item',
#                                                             'id': 'Q28609573',
#                                                             'numeric-id': 28609573}},
#                                     'property': 'P2860',
#                                     'snaktype': 'value'},
#                        'qualifiers': {},
#                        'qualifiers-order': [],
#                        'rank': 'normal',
#                        'references': [{'hash': 'e962d25052597ff81181c05c277866d8e0870606',
#                                        'snaks': {'P2410': [{'datatype': 'string',
#                                                             'datavalue': {'type': 'string',
#                                                                           'value': 'WP716'},
#                                                             'property': 'P2410',
#                                                             'snaktype': 'value'}],
#                                                  'P248': [{'datatype': 'wikibase-item',
#                                                            'datavalue': {'type': 'wikibase-entityid',
#                                                                          'value': {'entity-type': 'item',
#                                                                                    'id': 'Q7999828',
#                                                                                    'numeric-id': 7999828}},
#                                                            'property': 'P248',
#                                                            'snaktype': 'value'}],
#                                                  'P813': [{'datatype': 'time',
#                                                            'datavalue': {'type': 'time',
#                                                                          'value': {'after': 0,
#                                                                                    'before': 0,
#                                                                                    'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                    'precision': 11,
#                                                                                    'time': '+2019-09-04T00:00:00Z',
#                                                                                    'timezone': 0}},
#                                                            'property': 'P813',
#                                                            'snaktype': 'value'}]},
#                                        'snaks-order': ['P248',
#                                                        'P813',
#                                                        'P2410']}],
#                        'type': 'statement'},
#                       {'id': 'Q27436284$88EF75CA-C75B-42F6-B752-51289B29C99A',
#                        'mainsnak': {'datatype': 'wikibase-item',
#                                     'datavalue': {'type': 'wikibase-entityid',
#                                                   'value': {'entity-type': 'item',
#                                                             'id': 'Q28609605',
#                                                             'numeric-id': 28609605}},
#                                     'property': 'P2860',
#                                     'snaktype': 'value'},
#                        'qualifiers': {},
#                        'qualifiers-order': [],
#                        'rank': 'normal',
#                        'references': [{'hash': 'e962d25052597ff81181c05c277866d8e0870606',
#                                        'snaks': {'P2410': [{'datatype': 'string',
#                                                             'datavalue': {'type': 'string',
#                                                                           'value': 'WP716'},
#                                                             'property': 'P2410',
#                                                             'snaktype': 'value'}],
#                                                  'P248': [{'datatype': 'wikibase-item',
#                                                            'datavalue': {'type': 'wikibase-entityid',
#                                                                          'value': {'entity-type': 'item',
#                                                                                    'id': 'Q7999828',
#                                                                                    'numeric-id': 7999828}},
#                                                            'property': 'P248',
#                                                            'snaktype': 'value'}],
#                                                  'P813': [{'datatype': 'time',
#                                                            'datavalue': {'type': 'time',
#                                                                          'value': {'after': 0,
#                                                                                    'before': 0,
#                                                                                    'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                    'precision': 11,
#                                                                                    'time': '+2019-09-04T00:00:00Z',
#                                                                                    'timezone': 0}},
#                                                            'property': 'P813',
#                                                            'snaktype': 'value'}]},
#                                        'snaks-order': ['P248',
#                                                        'P813',
#                                                        'P2410']}],
#                        'type': 'statement'},
#                       {'id': 'Q27436284$384DB520-08B1-4777-A264-4FC83A598C97',
#                        'mainsnak': {'datatype': 'wikibase-item',
#                                     'datavalue': {'type': 'wikibase-entityid',
#                                                   'value': {'entity-type': 'item',
#                                                             'id': 'Q28609442',
#                                                             'numeric-id': 28609442}},
#                                     'property': 'P2860',
#                                     'snaktype': 'value'},
#                        'qualifiers': {},
#                        'qualifiers-order': [],
#                        'rank': 'normal',
#                        'references': [{'hash': 'e962d25052597ff81181c05c277866d8e0870606',
#                                        'snaks': {'P2410': [{'datatype': 'string',
#                                                             'datavalue': {'type': 'string',
#                                                                           'value': 'WP716'},
#                                                             'property': 'P2410',
#                                                             'snaktype': 'value'}],
#                                                  'P248': [{'datatype': 'wikibase-item',
#                                                            'datavalue': {'type': 'wikibase-entityid',
#                                                                          'value': {'entity-type': 'item',
#                                                                                    'id': 'Q7999828',
#                                                                                    'numeric-id': 7999828}},
#                                                            'property': 'P248',
#                                                            'snaktype': 'value'}],
#                                                  'P813': [{'datatype': 'time',
#                                                            'datavalue': {'type': 'time',
#                                                                          'value': {'after': 0,
#                                                                                    'before': 0,
#                                                                                    'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                    'precision': 11,
#                                                                                    'time': '+2019-09-04T00:00:00Z',
#                                                                                    'timezone': 0}},
#                                                            'property': 'P813',
#                                                            'snaktype': 'value'}]},
#                                        'snaks-order': ['P248',
#                                                        'P813',
#                                                        'P2410']}],
#                        'type': 'statement'},
#                       {'id': 'Q27436284$B18A3D36-0F4D-40DD-BB20-0CADEB13166F',
#                        'mainsnak': {'datatype': 'wikibase-item',
#                                     'datavalue': {'type': 'wikibase-entityid',
#                                                   'value': {'entity-type': 'item',
#                                                             'id': 'Q28316932',
#                                                             'numeric-id': 28316932}},
#                                     'property': 'P2860',
#                                     'snaktype': 'value'},
#                        'qualifiers': {},
#                        'qualifiers-order': [],
#                        'rank': 'normal',
#                        'references': [{'hash': 'e962d25052597ff81181c05c277866d8e0870606',
#                                        'snaks': {'P2410': [{'datatype': 'string',
#                                                             'datavalue': {'type': 'string',
#                                                                           'value': 'WP716'},
#                                                             'property': 'P2410',
#                                                             'snaktype': 'value'}],
#                                                  'P248': [{'datatype': 'wikibase-item',
#                                                            'datavalue': {'type': 'wikibase-entityid',
#                                                                          'value': {'entity-type': 'item',
#                                                                                    'id': 'Q7999828',
#                                                                                    'numeric-id': 7999828}},
#                                                            'property': 'P248',
#                                                            'snaktype': 'value'}],
#                                                  'P813': [{'datatype': 'time',
#                                                            'datavalue': {'type': 'time',
#                                                                          'value': {'after': 0,
#                                                                                    'before': 0,
#                                                                                    'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                    'precision': 11,
#                                                                                    'time': '+2019-09-04T00:00:00Z',
#                                                                                    'timezone': 0}},
#                                                            'property': 'P813',
#                                                            'snaktype': 'value'}]},
#                                        'snaks-order': ['P248',
#                                                        'P813',
#                                                        'P2410']}],
#                        'type': 'statement'},
#                       {'id': 'Q27436284$29AF2D4D-C939-4E3E-BAD9-032604301D49',
#                        'mainsnak': {'datatype': 'wikibase-item',
#                                     'datavalue': {'type': 'wikibase-entityid',
#                                                   'value': {'entity-type': 'item',
#                                                             'id': 'Q28609455',
#                                                             'numeric-id': 28609455}},
#                                     'property': 'P2860',
#                                     'snaktype': 'value'},
#                        'qualifiers': {},
#                        'qualifiers-order': [],
#                        'rank': 'normal',
#                        'references': [{'hash': 'e962d25052597ff81181c05c277866d8e0870606',
#                                        'snaks': {'P2410': [{'datatype': 'string',
#                                                             'datavalue': {'type': 'string',
#                                                                           'value': 'WP716'},
#                                                             'property': 'P2410',
#                                                             'snaktype': 'value'}],
#                                                  'P248': [{'datatype': 'wikibase-item',
#                                                            'datavalue': {'type': 'wikibase-entityid',
#                                                                          'value': {'entity-type': 'item',
#                                                                                    'id': 'Q7999828',
#                                                                                    'numeric-id': 7999828}},
#                                                            'property': 'P248',
#                                                            'snaktype': 'value'}],
#                                                  'P813': [{'datatype': 'time',
#                                                            'datavalue': {'type': 'time',
#                                                                          'value': {'after': 0,
#                                                                                    'before': 0,
#                                                                                    'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                    'precision': 11,
#                                                                                    'time': '+2019-09-04T00:00:00Z',
#                                                                                    'timezone': 0}},
#                                                            'property': 'P813',
#                                                            'snaktype': 'value'}]},
#                                        'snaks-order': ['P248',
#                                                        'P813',
#                                                        'P2410']}],
#                        'type': 'statement'},
#                       {'id': 'Q27436284$3FD25524-4161-42F3-9D0D-2B1FF821C5B4',
#                        'mainsnak': {'datatype': 'wikibase-item',
#                                     'datavalue': {'type': 'wikibase-entityid',
#                                                   'value': {'entity-type': 'item',
#                                                             'id': 'Q28609498',
#                                                             'numeric-id': 28609498}},
#                                     'property': 'P2860',
#                                     'snaktype': 'value'},
#                        'qualifiers': {},
#                        'qualifiers-order': [],
#                        'rank': 'normal',
#                        'references': [{'hash': 'e962d25052597ff81181c05c277866d8e0870606',
#                                        'snaks': {'P2410': [{'datatype': 'string',
#                                                             'datavalue': {'type': 'string',
#                                                                           'value': 'WP716'},
#                                                             'property': 'P2410',
#                                                             'snaktype': 'value'}],
#                                                  'P248': [{'datatype': 'wikibase-item',
#                                                            'datavalue': {'type': 'wikibase-entityid',
#                                                                          'value': {'entity-type': 'item',
#                                                                                    'id': 'Q7999828',
#                                                                                    'numeric-id': 7999828}},
#                                                            'property': 'P248',
#                                                            'snaktype': 'value'}],
#                                                  'P813': [{'datatype': 'time',
#                                                            'datavalue': {'type': 'time',
#                                                                          'value': {'after': 0,
#                                                                                    'before': 0,
#                                                                                    'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                    'precision': 11,
#                                                                                    'time': '+2019-09-04T00:00:00Z',
#                                                                                    'timezone': 0}},
#                                                            'property': 'P813',
#                                                            'snaktype': 'value'}]},
#                                        'snaks-order': ['P248',
#                                                        'P813',
#                                                        'P2410']}],
#                        'type': 'statement'},
#                       {'id': 'Q27436284$470BF9CB-596B-4D0B-80CD-6584A6F5EFD3',
#                        'mainsnak': {'datatype': 'wikibase-item',
#                                     'datavalue': {'type': 'wikibase-entityid',
#                                                   'value': {'entity-type': 'item',
#                                                             'id': 'Q28609596',
#                                                             'numeric-id': 28609596}},
#                                     'property': 'P2860',
#                                     'snaktype': 'value'},
#                        'qualifiers': {},
#                        'qualifiers-order': [],
#                        'rank': 'normal',
#                        'references': [{'hash': 'e962d25052597ff81181c05c277866d8e0870606',
#                                        'snaks': {'P2410': [{'datatype': 'string',
#                                                             'datavalue': {'type': 'string',
#                                                                           'value': 'WP716'},
#                                                             'property': 'P2410',
#                                                             'snaktype': 'value'}],
#                                                  'P248': [{'datatype': 'wikibase-item',
#                                                            'datavalue': {'type': 'wikibase-entityid',
#                                                                          'value': {'entity-type': 'item',
#                                                                                    'id': 'Q7999828',
#                                                                                    'numeric-id': 7999828}},
#                                                            'property': 'P248',
#                                                            'snaktype': 'value'}],
#                                                  'P813': [{'datatype': 'time',
#                                                            'datavalue': {'type': 'time',
#                                                                          'value': {'after': 0,
#                                                                                    'before': 0,
#                                                                                    'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                    'precision': 11,
#                                                                                    'time': '+2019-09-04T00:00:00Z',
#                                                                                    'timezone': 0}},
#                                                            'property': 'P813',
#                                                            'snaktype': 'value'}]},
#                                        'snaks-order': ['P248',
#                                                        'P813',
#                                                        'P2410']}],
#                        'type': 'statement'},
#                       {'id': 'Q27436284$0A4C4DB2-D3F3-4392-B1D6-1E6723FA00A5',
#                        'mainsnak': {'datatype': 'wikibase-item',
#                                     'datavalue': {'type': 'wikibase-entityid',
#                                                   'value': {'entity-type': 'item',
#                                                             'id': 'Q28645760',
#                                                             'numeric-id': 28645760}},
#                                     'property': 'P2860',
#                                     'snaktype': 'value'},
#                        'qualifiers': {},
#                        'qualifiers-order': [],
#                        'rank': 'normal',
#                        'references': [{'hash': 'e962d25052597ff81181c05c277866d8e0870606',
#                                        'snaks': {'P2410': [{'datatype': 'string',
#                                                             'datavalue': {'type': 'string',
#                                                                           'value': 'WP716'},
#                                                             'property': 'P2410',
#                                                             'snaktype': 'value'}],
#                                                  'P248': [{'datatype': 'wikibase-item',
#                                                            'datavalue': {'type': 'wikibase-entityid',
#                                                                          'value': {'entity-type': 'item',
#                                                                                    'id': 'Q7999828',
#                                                                                    'numeric-id': 7999828}},
#                                                            'property': 'P248',
#                                                            'snaktype': 'value'}],
#                                                  'P813': [{'datatype': 'time',
#                                                            'datavalue': {'type': 'time',
#                                                                          'value': {'after': 0,
#                                                                                    'before': 0,
#                                                                                    'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                    'precision': 11,
#                                                                                    'time': '+2019-09-04T00:00:00Z',
#                                                                                    'timezone': 0}},
#                                                            'property': 'P813',
#                                                            'snaktype': 'value'}]},
#                                        'snaks-order': ['P248',
#                                                        'P813',
#                                                        'P2410']}],
#                        'type': 'statement'},
#                       {'id': 'Q27436284$4DCB1F3F-708A-49F3-9A3D-DCCBE74B6187',
#                        'mainsnak': {'datatype': 'wikibase-item',
#                                     'datavalue': {'type': 'wikibase-entityid',
#                                                   'value': {'entity-type': 'item',
#                                                             'id': 'Q28645746',
#                                                             'numeric-id': 28645746}},
#                                     'property': 'P2860',
#                                     'snaktype': 'value'},
#                        'qualifiers': {},
#                        'qualifiers-order': [],
#                        'rank': 'normal',
#                        'references': [{'hash': 'e962d25052597ff81181c05c277866d8e0870606',
#                                        'snaks': {'P2410': [{'datatype': 'string',
#                                                             'datavalue': {'type': 'string',
#                                                                           'value': 'WP716'},
#                                                             'property': 'P2410',
# ...
#                                                           'snaktype': 'value'}]},
#                                       'snaks-order': ['P248',
#                                                       'P813',
#                                                       'P2410']}],
#                       'type': 'statement'},
#                      {'id': 'Q27436284$4A3CA76B-8977-4FC2-A1FE-D1C3DC54F4B3',
#                       'mainsnak': {'datatype': 'wikibase-item',
#                                    'datavalue': {'type': 'wikibase-entityid',
#                                                  'value': {'entity-type': 'item',
#                                                            'id': 'Q47459177',
#                                                            'numeric-id': 47459177}},
#                                    'property': 'P527',
#                                    'snaktype': 'value'},
#                       'qualifiers': {},
#                       'qualifiers-order': [],
#                       'rank': 'normal',
#                       'references': [{'hash': 'e962d25052597ff81181c05c277866d8e0870606',
#                                       'snaks': {'P2410': [{'datatype': 'string',
#                                                            'datavalue': {'type': 'string',
#                                                                          'value': 'WP716'},
#                                                            'property': 'P2410',
#                                                            'snaktype': 'value'}],
#                                                 'P248': [{'datatype': 'wikibase-item',
#                                                           'datavalue': {'type': 'wikibase-entityid',
#                                                                         'value': {'entity-type': 'item',
#                                                                                   'id': 'Q7999828',
#                                                                                   'numeric-id': 7999828}},
#                                                           'property': 'P248',
#                                                           'snaktype': 'value'}],
#                                                 'P813': [{'datatype': 'time',
#                                                           'datavalue': {'type': 'time',
#                                                                         'value': {'after': 0,
#                                                                                   'before': 0,
#                                                                                   'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                   'precision': 11,
#                                                                                   'time': '+2019-09-04T00:00:00Z',
#                                                                                   'timezone': 0}},
#                                                           'property': 'P813',
#                                                           'snaktype': 'value'}]},
#                                       'snaks-order': ['P248',
#                                                       'P813',
#                                                       'P2410']}],
#                       'type': 'statement'},
#                      {'id': 'Q27436284$92FD4BFC-CBBC-403E-A36F-4F758F40BFB3',
#                       'mainsnak': {'datatype': 'wikibase-item',
#                                    'datavalue': {'type': 'wikibase-entityid',
#                                                  'value': {'entity-type': 'item',
#                                                            'id': 'Q47459174',
#                                                            'numeric-id': 47459174}},
#                                    'property': 'P527',
#                                    'snaktype': 'value'},
#                       'qualifiers': {},
#                       'qualifiers-order': [],
#                       'rank': 'normal',
#                       'references': [{'hash': 'e962d25052597ff81181c05c277866d8e0870606',
#                                       'snaks': {'P2410': [{'datatype': 'string',
#                                                            'datavalue': {'type': 'string',
#                                                                          'value': 'WP716'},
#                                                            'property': 'P2410',
#                                                            'snaktype': 'value'}],
#                                                 'P248': [{'datatype': 'wikibase-item',
#                                                           'datavalue': {'type': 'wikibase-entityid',
#                                                                         'value': {'entity-type': 'item',
#                                                                                   'id': 'Q7999828',
#                                                                                   'numeric-id': 7999828}},
#                                                           'property': 'P248',
#                                                           'snaktype': 'value'}],
#                                                 'P813': [{'datatype': 'time',
#                                                           'datavalue': {'type': 'time',
#                                                                         'value': {'after': 0,
#                                                                                   'before': 0,
#                                                                                   'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                   'precision': 11,
#                                                                                   'time': '+2019-09-04T00:00:00Z',
#                                                                                   'timezone': 0}},
#                                                           'property': 'P813',
#                                                           'snaktype': 'value'}]},
#                                       'snaks-order': ['P248',
#                                                       'P813',
#                                                       'P2410']}],
#                       'type': 'statement'},
#                      {'id': 'Q27436284$7474FB86-4DD7-4ED7-83ED-A838B1D638F0',
#                       'mainsnak': {'datatype': 'wikibase-item',
#                                    'datavalue': {'type': 'wikibase-entityid',
#                                                  'value': {'entity-type': 'item',
#                                                            'id': 'Q27070772',
#                                                            'numeric-id': 27070772}},
#                                    'property': 'P527',
#                                    'snaktype': 'value'},
#                       'qualifiers': {},
#                       'qualifiers-order': [],
#                       'rank': 'normal',
#                       'references': [{'hash': 'e962d25052597ff81181c05c277866d8e0870606',
#                                       'snaks': {'P2410': [{'datatype': 'string',
#                                                            'datavalue': {'type': 'string',
#                                                                          'value': 'WP716'},
#                                                            'property': 'P2410',
#                                                            'snaktype': 'value'}],
#                                                 'P248': [{'datatype': 'wikibase-item',
#                                                           'datavalue': {'type': 'wikibase-entityid',
#                                                                         'value': {'entity-type': 'item',
#                                                                                   'id': 'Q7999828',
#                                                                                   'numeric-id': 7999828}},
#                                                           'property': 'P248',
#                                                           'snaktype': 'value'}],
#                                                 'P813': [{'datatype': 'time',
#                                                           'datavalue': {'type': 'time',
#                                                                         'value': {'after': 0,
#                                                                                   'before': 0,
#                                                                                   'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                   'precision': 11,
#                                                                                   'time': '+2019-09-04T00:00:00Z',
#                                                                                   'timezone': 0}},
#                                                           'property': 'P813',
#                                                           'snaktype': 'value'}]},
#                                       'snaks-order': ['P248',
#                                                       'P813',
#                                                       'P2410']}],
#                       'type': 'statement'},
#                      {'id': 'Q27436284$57AA9788-5261-49BD-AE7E-D69E4AC7BD66',
#                       'mainsnak': {'datatype': 'wikibase-item',
#                                    'datavalue': {'type': 'wikibase-entityid',
#                                                  'value': {'entity-type': 'item',
#                                                            'id': 'Q27070771',
#                                                            'numeric-id': 27070771}},
#                                    'property': 'P527',
#                                    'snaktype': 'value'},
#                       'qualifiers': {},
#                       'qualifiers-order': [],
#                       'rank': 'normal',
#                       'references': [{'hash': 'e962d25052597ff81181c05c277866d8e0870606',
#                                       'snaks': {'P2410': [{'datatype': 'string',
#                                                            'datavalue': {'type': 'string',
#                                                                          'value': 'WP716'},
#                                                            'property': 'P2410',
#                                                            'snaktype': 'value'}],
#                                                 'P248': [{'datatype': 'wikibase-item',
#                                                           'datavalue': {'type': 'wikibase-entityid',
#                                                                         'value': {'entity-type': 'item',
#                                                                                   'id': 'Q7999828',
#                                                                                   'numeric-id': 7999828}},
#                                                           'property': 'P248',
#                                                           'snaktype': 'value'}],
#                                                 'P813': [{'datatype': 'time',
#                                                           'datavalue': {'type': 'time',
#                                                                         'value': {'after': 0,
#                                                                                   'before': 0,
#                                                                                   'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                   'precision': 11,
#                                                                                   'time': '+2019-09-04T00:00:00Z',
#                                                                                   'timezone': 0}},
#                                                           'property': 'P813',
#                                                           'snaktype': 'value'}]},
#                                       'snaks-order': ['P248',
#                                                       'P813',
#                                                       'P2410']}],
#                       'type': 'statement'}],
#             'P703': [{'id': 'Q27436284$1D5FFD43-8A96-4396-8963-326F3BA9167C',
#                       'mainsnak': {'datatype': 'wikibase-item',
#                                    'datavalue': {'type': 'wikibase-entityid',
#                                                  'value': {'entity-type': 'item',
#                                                            'id': 'Q15978631',
#                                                            'numeric-id': 15978631}},
#                                    'property': 'P703',
#                                    'snaktype': 'value'},
#                       'qualifiers': {},
#                       'qualifiers-order': [],
#                       'rank': 'normal',
#                       'references': [{'hash': 'e962d25052597ff81181c05c277866d8e0870606',
#                                       'snaks': {'P2410': [{'datatype': 'string',
#                                                            'datavalue': {'type': 'string',
#                                                                          'value': 'WP716'},
#                                                            'property': 'P2410',
#                                                            'snaktype': 'value'}],
#                                                 'P248': [{'datatype': 'wikibase-item',
#                                                           'datavalue': {'type': 'wikibase-entityid',
#                                                                         'value': {'entity-type': 'item',
#                                                                                   'id': 'Q7999828',
#                                                                                   'numeric-id': 7999828}},
#                                                           'property': 'P248',
#                                                           'snaktype': 'value'}],
#                                                 'P813': [{'datatype': 'time',
#                                                           'datavalue': {'type': 'time',
#                                                                         'value': {'after': 0,
#                                                                                   'before': 0,
#                                                                                   'calendarmodel': 'http://www.wikidata.org/entity/Q1985727',
#                                                                                   'precision': 11,
#                                                                                   'time': '+2019-09-04T00:00:00Z',
#                                                                                   'timezone': 0}},
#                                                           'property': 'P813',
#                                                           'snaktype': 'value'}]},
#                                       'snaks-order': ['P248',
#                                                       'P813',
#                                                       'P2410']}],
#                       'type': 'statement'}]},
#  'descriptions': {'en': {'language': 'en',
#                          'value': 'biological pathway in human'}},
#  'labels': {'en': {'language': 'en',
#                    'value': 'Vitamin A and Carotenoid Metabolism'}},
#  'sitelinks': {}}

# %% [markdown]
# ## Get the description from Wikipathways

# %%
query = """
prefix dcterms:	<http://purl.org/dc/terms/>
SELECT ?item ?description WHERE { <"""
query += wdwpid + "> " 
query += """wdt:P2410 ?wpid ;
         wdt:P2888 ?wpiri .
  SERVICE <http://sparql.wikipathways.org/> {
      # ?version dc:identifier ?wpiri ;
               dcterms:description ?description .
    }
}
"""
sparqlpandas(query, endpoint="https://query.wikidata.org/sparql")
# Out:
#                                          description
# 0  This pathway is about carotenoid and vitamin A...

# %%
description = sparql(query, endpoint="https://query.wikidata.org/sparql")["results"]["bindings"][0]["description"]["value"]
print(description)
# Out:
# This pathway is about carotenoid and vitamin A metabolism. The initial version was created by the NuGO focusteam on Carotenoid metabolism. It was used to test a text mining workflow which added some additional entities (see Waagmeester et al. 2009 [https://www.ncbi.nlm.nih.gov/pubmed/19715393]).

# %%
wdPage.set_description(description, lang="en")
wdPage.write(login)
# Out:
# Error while writing to Wikidata
# ---------------------------------------------------------------------------
# WDApiError                                Traceback (most recent call last)
# <ipython-input-31-fe99cc2d8eb0> in <module>
#       1 wdPage.set_description(description, lang="en")
# ----> 2 wdPage.write(login)
#
# /usr/local/lib/python3.7/site-packages/wikidataintegrator/wdi_core.py in write(self, login, bot_account, edit_summary, entity_type, property_datatype, max_retries, retry_after)
#     942                     raise NonUniqueLabelDescriptionPairError(json_data)
#     943                 else:
# --> 944                     raise WDApiError(json_data)
#     945             elif 'error' in json_data.keys():
#     946                 raise WDApiError(json_data)
#
# WDApiError: {'error': {'code': 'modification-failed', 'info': 'Description must be no more than 250 characters long', 'messages': [{'name': 'wikibase-validator-description-too-long', 'parameters': ['250', 'This pathway is about caroten...'], 'html': {'*': 'Description must be no more than 250 characters long'}}], '*': 'See https://www.wikidata.org/w/api.php for API usage. Subscribe to the mediawiki-api-announce mailing list at &lt;https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce&gt; for notice of API deprecations and breaking changes.'}, 'servedby': 'mw1286'}
